# %%
#standard imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import tensorflow and keras
import tensorflow as tf
from tensorflow import keras

import seaborn as sns
sns.set(style= "darkgrid", color_codes = True)
from tensorflow.keras.applications import VGG16

#import generic model class
from tensorflow.keras import Model, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.regularizers import l2
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy
from sklearn.metrics import roc_curve, auc
from tensorflow.keras.preprocessing.image import  load_img, ImageDataGenerator
from keras.optimizers import RMSprop,Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
import warnings
warnings.filterwarnings('ignore')

#import random
import random as rn
from random import randrange

#Usefull imports from kaggle
import glob
from PIL import Image
import os
import cv2

#function for fast generation of training and test set from data
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import AvgPool2D
# Out:
# 2023-08-21 11:38:23.237830: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-21 11:38:23.517890: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-21 11:38:23.519736: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-21 11:38:24.437268: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Define image size and other parameterst 

path = '/home/giacomo/git/Tittarelli_Giacomo_RetiNeurali/chest_xray/chest_xray/'
dimension = 50
img_width, img_height = dimension, dimension
batchsize = 32
num_of_class = 2

train = keras. utils.image_dataset_from_directory(
    directory= path + 'train',
    labels='inferred',
    label_mode='categorical',
    batch_size=batchsize,
    image_size=(img_width, img_height))

validation = keras. utils.image_dataset_from_directory(
    directory= path + 'val',
    labels='inferred',
    label_mode='categorical',
    batch_size=batchsize,
    image_size=(img_width, img_height))

test = keras. utils.image_dataset_from_directory(
    directory= path + 'test',
    labels='inferred',
    label_mode='categorical',
    batch_size=batchsize,
    image_size=(img_width, img_height))
# Out:
# Found 5216 files belonging to 2 classes.
# Found 16 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.

# %%
# define paths
train_normal_dir = path + 'train/NORMAL/'
train_pneu_dir = path + 'train/PNEUMONIA/'

test_normal_dir = path + 'test/NORMAL/'
test_pneu_dir = path + 'test/PNEUMONIA/'

val_normal_dir = path + 'val/NORMAL/'
val_pneu_dir = path + 'val/PNEUMONIA/'


# find all files, our files has extension jpeg
train_normal_cases = glob.glob(train_normal_dir + '*jpeg')
train_pneu_cases = glob.glob(train_pneu_dir + '*jpeg')

test_normal_cases = glob.glob(test_normal_dir + '*jpeg')
test_pneu_cases = glob.glob(test_pneu_dir + '*jpeg')

val_normal_cases = glob.glob(val_normal_dir + '*jpeg')
val_pneu_cases = glob.glob(val_pneu_dir + '*jpeg')


# create lists for train, test & validation cases, create labels as well
train_list = []
test_list = []
val_list = []

for x in train_normal_cases:
    train_list.append([x, 0])
    
for x in train_pneu_cases:
    train_list.append([x, 1])
    
for x in test_normal_cases:
    test_list.append([x, 0])
    
for x in test_pneu_cases:
    test_list.append([x, 1])
    
for x in val_normal_cases:
    val_list.append([x, 0])
    
for x in val_pneu_cases:
    val_list.append([x, 1])


# shuffle/randomize data as they were loaded in order: normal cases, then pneumonia cases
rn.shuffle(train_list)
rn.shuffle(test_list)
rn.shuffle(val_list)


# create dataframes
train_df = pd.DataFrame(train_list, columns=['image', 'label'])
test_df = pd.DataFrame(test_list, columns=['image', 'label'])
val_df = pd.DataFrame(val_list, columns=['image', 'label'])

# %%
# Some plots before to go

plt.figure(figsize=(20,8))
for i,img_path in enumerate(train_df[train_df['label'] == 1][0:4]['image']):
    plt.subplot(2,4,i+1)
    plt.axis('off')
    img = plt.imread(img_path)
    plt.imshow(img, cmap='gray')
    plt.title('Pneumonia')
    
for i,img_path in enumerate(train_df[train_df['label'] == 0][0:4]['image']):
    plt.subplot(2,4,4+i+1)
    plt.axis('off')
    img = plt.imread(img_path)
    plt.imshow(img, cmap='gray')
    plt.title('Healthy / Normal')

# %%
# Proprocess the data
# RESIZE IMPORTANTE PER VELOCIZZARE ALGORITMO

resize = 34

def process_data(img_path):
    img = cv2.imread(img_path)
    img = cv2.resize(img, (resize, resize))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = img/255.0
    img = np.reshape(img, (resize,resize,1))
    
    return img

def compose_dataset(df):
    data = []
    labels = []

    for img_path, label in df.values:
        data.append(process_data(img_path))
        labels.append(label)
        
    return np.array(data), np.array(labels)

# %%
X_train, y_train = compose_dataset(train_df)
X_test, y_test = compose_dataset(test_df)
X_val, y_val = compose_dataset(val_df)

print('Train data shape: {}, Labels shape: {}'.format(X_train.shape, y_train.shape))
print('Test data shape: {}, Labels shape: {}'.format(X_test.shape, y_test.shape))
print('Validation data shape: {}, Labels shape: {}'.format(X_val.shape, y_val.shape))
# Out:
# Train data shape: (5216, 34, 34, 1), Labels shape: (5216,)
# Test data shape: (624, 34, 34, 1), Labels shape: (624,)
# Validation data shape: (16, 34, 34, 1), Labels shape: (16,)

# %%
# define generator
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range = 0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    vertical_flip=False
)

# fit generator on our train features
datagen.fit(X_train)

y_train_cat = keras.utils.to_categorical(y_train, num_of_class)
y_val_cat = keras.utils.to_categorical(y_val, num_of_class)
y_test_cat = keras.utils.to_categorical(y_test, num_of_class)

# %%
resize = 34

model = Sequential()

model.add(Conv2D(filters=8, kernel_size=(7,7), padding='same', activation='relu', input_shape=(resize, resize, 1)))
model.add(Conv2D(filters=8, kernel_size=(7,7), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=16, kernel_size=(5,5), padding='same', activation='relu'))
model.add(Conv2D(filters=16, kernel_size=(5,5), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(2, activation='softmax'))

optimizer = Adam(learning_rate=0.0001, weight_decay=1e-5)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

callback = EarlyStopping(monitor='loss', patience=6)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 34, 34, 8)         400
#
#  conv2d_9 (Conv2D)           (None, 34, 34, 8)         3144
#
#  max_pooling2d_4 (MaxPoolin  (None, 17, 17, 8)         0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 17, 17, 16)        3216
#
#  conv2d_11 (Conv2D)          (None, 17, 17, 16)        6416
#
#  max_pooling2d_5 (MaxPoolin  (None, 8, 8, 16)          0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 32)          4640
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 32)          9248
#
#  max_pooling2d_6 (MaxPoolin  (None, 4, 4, 32)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 128)               65664
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 92986 (363.23 KB)
# Trainable params: 92986 (363.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Define some hyperparameter
# Sei su codice di prova! Fai massimo 2 epoche!
epochs = 30
batch_size = 6

# %%
# Train the model

history = model.fit(
    datagen.flow(X_train, y_train_cat, batch_size=batch_size),
    validation_data=(X_test, y_test_cat),
    epochs=epochs,
    verbose=1,
    callbacks=[callback],
)
# Out:
# Epoch 1/30
# 870/870 [==============================] - 15s 17ms/step - loss: 0.4610 - accuracy: 0.7931 - val_loss: 0.4033 - val_accuracy: 0.8077
# Epoch 2/30
# 870/870 [==============================] - 15s 17ms/step - loss: 0.2967 - accuracy: 0.8763 - val_loss: 0.4162 - val_accuracy: 0.8253
# Epoch 3/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.2493 - accuracy: 0.8992 - val_loss: 0.3898 - val_accuracy: 0.8237
# Epoch 4/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.2296 - accuracy: 0.9022 - val_loss: 0.3933 - val_accuracy: 0.8301
# Epoch 5/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.2108 - accuracy: 0.9133 - val_loss: 0.5108 - val_accuracy: 0.7837
# Epoch 6/30
# 870/870 [==============================] - 13s 15ms/step - loss: 0.1948 - accuracy: 0.9199 - val_loss: 0.3286 - val_accuracy: 0.8510
# Epoch 7/30
# 870/870 [==============================] - 13s 15ms/step - loss: 0.1853 - accuracy: 0.9204 - val_loss: 0.3902 - val_accuracy: 0.8237
# Epoch 8/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1705 - accuracy: 0.9279 - val_loss: 0.5107 - val_accuracy: 0.8253
# Epoch 9/30
# 870/870 [==============================] - 13s 15ms/step - loss: 0.1653 - accuracy: 0.9350 - val_loss: 0.3316 - val_accuracy: 0.8654
# Epoch 10/30
# 870/870 [==============================] - 13s 15ms/step - loss: 0.1609 - accuracy: 0.9339 - val_loss: 0.3875 - val_accuracy: 0.8462
# Epoch 11/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1516 - accuracy: 0.9392 - val_loss: 0.3400 - val_accuracy: 0.8718
# Epoch 12/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1407 - accuracy: 0.9450 - val_loss: 0.3551 - val_accuracy: 0.8478
# Epoch 13/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1444 - accuracy: 0.9433 - val_loss: 0.3435 - val_accuracy: 0.8702
# Epoch 14/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1406 - accuracy: 0.9456 - val_loss: 0.3139 - val_accuracy: 0.8782
# Epoch 15/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1397 - accuracy: 0.9427 - val_loss: 0.3391 - val_accuracy: 0.8766
# Epoch 16/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1374 - accuracy: 0.9440 - val_loss: 0.4704 - val_accuracy: 0.8317
# Epoch 17/30
# 870/870 [==============================] - 13s 15ms/step - loss: 0.1320 - accuracy: 0.9484 - val_loss: 0.3510 - val_accuracy: 0.8574
# Epoch 18/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1360 - accuracy: 0.9459 - val_loss: 0.2596 - val_accuracy: 0.8910
# Epoch 19/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1315 - accuracy: 0.9467 - val_loss: 0.3471 - val_accuracy: 0.8830
# Epoch 20/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1310 - accuracy: 0.9486 - val_loss: 0.3470 - val_accuracy: 0.8830
# Epoch 21/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1264 - accuracy: 0.9502 - val_loss: 0.3412 - val_accuracy: 0.8734
# Epoch 22/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1255 - accuracy: 0.9513 - val_loss: 0.4273 - val_accuracy: 0.8558
# Epoch 23/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1298 - accuracy: 0.9494 - val_loss: 0.3023 - val_accuracy: 0.8814
# Epoch 24/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1194 - accuracy: 0.9530 - val_loss: 0.3926 - val_accuracy: 0.8526
# Epoch 25/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1213 - accuracy: 0.9530 - val_loss: 0.4116 - val_accuracy: 0.8413
# Epoch 26/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1243 - accuracy: 0.9496 - val_loss: 0.3122 - val_accuracy: 0.8766
# Epoch 27/30
# 870/870 [==============================] - 15s 17ms/step - loss: 0.1133 - accuracy: 0.9565 - val_loss: 0.4279 - val_accuracy: 0.8478
# Epoch 28/30
# 870/870 [==============================] - 14s 16ms/step - loss: 0.1180 - accuracy: 0.9549 - val_loss: 0.3919 - val_accuracy: 0.8462
# Epoch 29/30
# 870/870 [==============================] - 13s 15ms/step - loss: 0.1207 - accuracy: 0.9525 - val_loss: 0.3130 - val_accuracy: 0.8926
# Epoch 30/30
# 870/870 [==============================] - 13s 15ms/step - loss: 0.1167 - accuracy: 0.9532 - val_loss: 0.3633 - val_accuracy: 0.8686

# %%
#plot learning curves

fig, ax = plt.subplots(figsize=(8,6))

for metric in history.history:
    
    #subtract half epoch from training data
    if len(metric.split('_')) < 2:
        ax.plot(np.array(history.epoch)-.5, history.history[metric], label=metric)
    else:
        ax.plot(history.epoch, history.history[metric], label=metric)
    
ax.grid()    

ax.legend(fontsize=15);

# %%
# Randomize 

seed_value = 42
rn.seed(seed_value)

# %%
#identify wrong predictions in the training set

y_train_pred = model.predict(X_train).argmax(axis=1)
# Out:
# 163/163 [==============================] - 1s 8ms/step

# %%
idx_wrong = np.where(y_train_pred != y_train)[0] #positions of the wrongly classified data

num_wrong = len(idx_wrong)
print(num_wrong)
# Out:
# 184

# %%
# show the first 10 wrong predictions the training set

fig, axs = plt.subplots(2,5,figsize=(12,4))

for i in range(10):
    
    ax = axs.ravel()[i]
    
    idx = idx_wrong[randrange(0, num_wrong)]
    
    ax.imshow(X_train[idx], cmap='gray')
    ax.set_title('TRUE: {}, PRED {}'.format(y_train[idx], y_train_pred[idx]), fontsize=13)
    ax.axis('off')

# %%
#identify correct predictions in the training set

y_train_pred = model.predict(X_train).argmax(axis=1)

idx_correct = np.where(y_train_pred == y_train)[0] #positions of the wrongly classified data

num_correct = len(idx_correct)

print(num_correct)
# Out:
# 163/163 [==============================] - 1s 8ms/step
# 5032

# %%
# show 10 correct predictions the training set

fig, axs = plt.subplots(2,5,figsize=(12,4))

for i in range(10):
    
    ax = axs.ravel()[i]
    
    idx = idx_correct[randrange(0, num_correct)]
    
    ax.imshow(X_train[idx], cmap='gray')
    ax.set_title('TRUE: {}, PRED {}'.format(y_train[idx], y_train_pred[idx]), fontsize=13)
    ax.axis('off')
