# %%
#standard imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow import keras

#import generic model class
from tensorflow.keras import Model, Input

#imports for CNN model construction
from keras.regularizers import l2
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers.legacy import Adam
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import  load_img, ImageDataGenerator
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, AvgPool2D
from sklearn.model_selection import KFold

#import for study the performance of the model
from sklearn.metrics import roc_curve, auc, confusion_matrix

#imports for confusion matrix
import seaborn as sns
sns.set(style= "darkgrid", color_codes = True)
from keras.applications import VGG16

#imports for draw the model
import graphviz
import pydot
from keras.utils import plot_model
from IPython.display import Image

#imports random
import random as rn
from random import randrange

#imports for preprocessing the data
import glob
import os
import cv2

# %%
# Define a seed value for the random operations
# Apparently you may use different seed values at each stage
seed_value= 0

# 1. Set the `PYTHONHASHSEED` environment variable at a fixed value
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set the `python` built-in pseudo-random generator at a fixed value
rn.seed(seed_value)

# 3. Set the `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
tf.random.set_seed(seed_value)
# for later versions: 
# tf.compat.v1.set_random_seed(seed_value)

# 5. Configure a new global `tensorflow` session
#from keras import backend as K
#session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
#sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
#K.set_session(sess)
# for later versions:
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

# %%
# Define image size and other parameterst 

path = '/Users/giac/git/Tittarelli_Giacomo_RetiNeurali/chest_xray/'
dimension = 250
img_width, img_height = dimension, dimension
batchsize = 32
num_of_class = 2

train = keras. utils.image_dataset_from_directory(
    directory= path + 'train',
    labels='inferred',
    label_mode='categorical',
    batch_size=batchsize,
    image_size=(img_width, img_height))

test = keras. utils.image_dataset_from_directory(
    directory= path + 'test',
    labels='inferred',
    label_mode='categorical',
    batch_size=batchsize,
    image_size=(img_width, img_height))
# Out:
# Found 5216 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.

# %%
# define paths
train_normal_dir = path + 'train/NORMAL/'
train_pneu_dir = path + 'train/PNEUMONIA/'

test_normal_dir = path + 'test/NORMAL/'
test_pneu_dir = path + 'test/PNEUMONIA/'

# find all files, our files has extension jpeg
train_normal_cases = glob.glob(train_normal_dir + '*jpeg')
train_pneu_cases = glob.glob(train_pneu_dir + '*jpeg')

test_normal_cases = glob.glob(test_normal_dir + '*jpeg')
test_pneu_cases = glob.glob(test_pneu_dir + '*jpeg')

# create lists for train, test & validation cases, create labels as well
train_list = []
test_list = []
val_list = []

for x in train_normal_cases:
    train_list.append([x, 0])
    
for x in train_pneu_cases:
    train_list.append([x, 1])
    
for x in test_normal_cases:
    test_list.append([x, 0])
    
for x in test_pneu_cases:
    test_list.append([x, 1])
    
# shuffle/randomize data as they were loaded in order: normal cases, then pneumonia cases
rn.shuffle(train_list)
rn.shuffle(test_list)

# create dataframes
train_df = pd.DataFrame(train_list, columns=['image', 'label'])
test_df = pd.DataFrame(test_list, columns=['image', 'label'])

# %%
# Some plots before to go

plt.figure(figsize=(20,8))
for i,img_path in enumerate(train_df[train_df['label'] == 1][0:2]['image']):
    plt.subplot(2,4,i+1)
    plt.axis('off')
    img = plt.imread(img_path)
    plt.imshow(img, cmap='gray')
    plt.title('Pneumonia')
    
for i,img_path in enumerate(train_df[train_df['label'] == 0][0:2]['image']):
    plt.subplot(2,4,4+i+1)
    plt.axis('off')
    img = plt.imread(img_path)
    plt.imshow(img, cmap='gray')
    plt.title('Healthy / Normal')

# %%
# Preprocessing the data. It's important to resize the images in order to reduce the computational cost of the alghoritm
resize = 68

def process_data(img_path):
    img = cv2.imread(img_path)
    img = cv2.resize(img, (resize, resize))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = img/255.0
    img = np.reshape(img, (resize,resize,1))
    
    return img

def compose_dataset(df):
    data = []
    labels = []

    for img_path, label in df.values:
        data.append(process_data(img_path))
        labels.append(label)
        
    return np.array(data), np.array(labels)

# %%
X_train, y_train = compose_dataset(train_df)
X_test, y_test = compose_dataset(test_df)

# Validation set
val_size = .03

# Generate training and test set with stratification
# This means that we will find the same proportion of classes bot in the validation and in the training set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=val_size, stratify=y_train)

print('Train data shape: {}, Labels shape: {}'.format(X_train.shape, y_train.shape))
print('Test data shape: {}, Labels shape: {}'.format(X_test.shape, y_test.shape))
print('Validation data shape: {}, Labels shape: {}'.format(X_val.shape, y_val.shape))
# Out:
# Train data shape: (5059, 68, 68, 1), Labels shape: (5059,)
# Test data shape: (624, 68, 68, 1), Labels shape: (624,)
# Validation data shape: (157, 68, 68, 1), Labels shape: (157,)

# %%
plt.hist(y_train, bins=np.linspace(0,2,3), rwidth=.8)
plt.xticks(range(3))
plt.xlabel("  Normal                                           Pneumonia")
# Out:
# Text(0.5, 0, '  Normal                                           Pneumonia')

# %%
# define generator for data augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range = 0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    vertical_flip=False
)

# fit generator on our train features
datagen.fit(X_train)

y_train_cat = keras.utils.to_categorical(y_train, num_of_class)
y_test_cat = keras.utils.to_categorical(y_test, num_of_class)
y_val_cat = keras.utils.to_categorical(y_val, num_of_class)

# %%
# Model 
model = Sequential()

model.add(Conv2D(filters=8, kernel_size=(7,7), padding='same', activation='relu', input_shape=(resize, resize, 1)))
#model.add(Conv2D(filters=8, kernel_size=(7,7), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=16, kernel_size=(5,5), padding='same', activation='relu'))
model.add(Conv2D(filters=16, kernel_size=(5,5), padding='same', activation='relu'))
#model.add(Conv2D(filters=16, kernel_size=(5,5), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

#model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
#model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
#model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
#model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.03)))
model.add(Dropout(0.2))
model.add(Dense(2, activation='sigmoid'))

optimizer = Adam(learning_rate=0.0005, decay=1e-5)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

callback = EarlyStopping(monitor='loss', patience=6)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 68, 68, 8)         400
#
#  max_pooling2d (MaxPooling2  (None, 34, 34, 8)         0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 34, 34, 16)        3216
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 16)        6416
#
#  max_pooling2d_1 (MaxPoolin  (None, 17, 17, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 4624)              0
#
#  dense (Dense)               (None, 128)               592000
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 618802 (2.36 MB)
# Trainable params: 618802 (2.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
keras.utils.plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=True,
    show_trainable=False,
)

# %%
# Define some hyperparameter
epochs = 100
batch_size = 8

# %%
# Train the model

history = model.fit(
    datagen.flow(X_train, y_train_cat, batch_size=batch_size),
    validation_data=(X_val, y_val_cat),
    epochs=epochs,
    verbose=1,
    callbacks=[callback],
)
# Out:
# Epoch 1/100
# 633/633 [==============================] - 15s 23ms/step - loss: 1.0648 - accuracy: 0.8087 - val_loss: 0.2458 - val_accuracy: 0.9554
# Epoch 2/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.2781 - accuracy: 0.8974 - val_loss: 0.1458 - val_accuracy: 0.9490
# Epoch 3/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.2309 - accuracy: 0.9160 - val_loss: 0.1407 - val_accuracy: 0.9363
# Epoch 4/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1976 - accuracy: 0.9269 - val_loss: 0.1087 - val_accuracy: 0.9427
# Epoch 5/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1937 - accuracy: 0.9294 - val_loss: 0.1651 - val_accuracy: 0.9363
# Epoch 6/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1725 - accuracy: 0.9342 - val_loss: 0.1079 - val_accuracy: 0.9554
# Epoch 7/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1725 - accuracy: 0.9365 - val_loss: 0.1156 - val_accuracy: 0.9554
# Epoch 8/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1664 - accuracy: 0.9409 - val_loss: 0.1082 - val_accuracy: 0.9618
# Epoch 9/100
# 633/633 [==============================] - 121s 191ms/step - loss: 0.1575 - accuracy: 0.9395 - val_loss: 0.0996 - val_accuracy: 0.9554
# Epoch 10/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1458 - accuracy: 0.9445 - val_loss: 0.1165 - val_accuracy: 0.9554
# Epoch 11/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1441 - accuracy: 0.9492 - val_loss: 0.1046 - val_accuracy: 0.9554
# Epoch 12/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1480 - accuracy: 0.9462 - val_loss: 0.1040 - val_accuracy: 0.9554
# Epoch 13/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1361 - accuracy: 0.9492 - val_loss: 0.1943 - val_accuracy: 0.9299
# Epoch 14/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1482 - accuracy: 0.9456 - val_loss: 0.1155 - val_accuracy: 0.9618
# Epoch 15/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1467 - accuracy: 0.9458 - val_loss: 0.0974 - val_accuracy: 0.9618
# Epoch 16/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1295 - accuracy: 0.9520 - val_loss: 0.1126 - val_accuracy: 0.9554
# Epoch 17/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1304 - accuracy: 0.9520 - val_loss: 0.0967 - val_accuracy: 0.9618
# Epoch 18/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1263 - accuracy: 0.9512 - val_loss: 0.0795 - val_accuracy: 0.9745
# Epoch 19/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1243 - accuracy: 0.9559 - val_loss: 0.0719 - val_accuracy: 0.9682
# Epoch 20/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1213 - accuracy: 0.9577 - val_loss: 0.1018 - val_accuracy: 0.9618
# Epoch 21/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1228 - accuracy: 0.9579 - val_loss: 0.0853 - val_accuracy: 0.9682
# Epoch 22/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1210 - accuracy: 0.9569 - val_loss: 0.0878 - val_accuracy: 0.9745
# Epoch 23/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1177 - accuracy: 0.9607 - val_loss: 0.0674 - val_accuracy: 0.9682
# Epoch 24/100
# 633/633 [==============================] - 91s 144ms/step - loss: 0.1137 - accuracy: 0.9553 - val_loss: 0.0800 - val_accuracy: 0.9682
# Epoch 25/100
# 633/633 [==============================] - 30s 48ms/step - loss: 0.1110 - accuracy: 0.9620 - val_loss: 0.0699 - val_accuracy: 0.9809
# Epoch 26/100
# 633/633 [==============================] - 15s 24ms/step - loss: 0.1119 - accuracy: 0.9599 - val_loss: 0.1224 - val_accuracy: 0.9745
# Epoch 27/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1047 - accuracy: 0.9617 - val_loss: 0.0602 - val_accuracy: 0.9745
# Epoch 28/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1042 - accuracy: 0.9640 - val_loss: 0.0729 - val_accuracy: 0.9745
# Epoch 29/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1053 - accuracy: 0.9624 - val_loss: 0.0907 - val_accuracy: 0.9554
# Epoch 30/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1073 - accuracy: 0.9622 - val_loss: 0.0843 - val_accuracy: 0.9745
# Epoch 31/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1145 - accuracy: 0.9615 - val_loss: 0.0730 - val_accuracy: 0.9618
# Epoch 32/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1069 - accuracy: 0.9654 - val_loss: 0.0712 - val_accuracy: 0.9618
# Epoch 33/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0983 - accuracy: 0.9678 - val_loss: 0.1058 - val_accuracy: 0.9745
# Epoch 34/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1036 - accuracy: 0.9622 - val_loss: 0.0854 - val_accuracy: 0.9682
# Epoch 35/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1049 - accuracy: 0.9644 - val_loss: 0.0855 - val_accuracy: 0.9745
# Epoch 36/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0912 - accuracy: 0.9688 - val_loss: 0.0669 - val_accuracy: 0.9682
# Epoch 37/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0983 - accuracy: 0.9652 - val_loss: 0.0792 - val_accuracy: 0.9745
# Epoch 38/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0896 - accuracy: 0.9686 - val_loss: 0.0637 - val_accuracy: 0.9682
# Epoch 39/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.1003 - accuracy: 0.9658 - val_loss: 0.0775 - val_accuracy: 0.9682
# Epoch 40/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0969 - accuracy: 0.9662 - val_loss: 0.0601 - val_accuracy: 0.9682
# Epoch 41/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0961 - accuracy: 0.9668 - val_loss: 0.0692 - val_accuracy: 0.9554
# Epoch 42/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0917 - accuracy: 0.9676 - val_loss: 0.0624 - val_accuracy: 0.9745
# Epoch 43/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0899 - accuracy: 0.9713 - val_loss: 0.0686 - val_accuracy: 0.9745
# Epoch 44/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0893 - accuracy: 0.9733 - val_loss: 0.0781 - val_accuracy: 0.9554
# Epoch 45/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0926 - accuracy: 0.9678 - val_loss: 0.0741 - val_accuracy: 0.9618
# Epoch 46/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0855 - accuracy: 0.9707 - val_loss: 0.0620 - val_accuracy: 0.9809
# Epoch 47/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0866 - accuracy: 0.9684 - val_loss: 0.0887 - val_accuracy: 0.9618
# Epoch 48/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0911 - accuracy: 0.9686 - val_loss: 0.0747 - val_accuracy: 0.9682
# Epoch 49/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0874 - accuracy: 0.9696 - val_loss: 0.0801 - val_accuracy: 0.9745
# Epoch 50/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0865 - accuracy: 0.9703 - val_loss: 0.0757 - val_accuracy: 0.9682
# Epoch 51/100
# 633/633 [==============================] - 15s 24ms/step - loss: 0.0808 - accuracy: 0.9721 - val_loss: 0.0992 - val_accuracy: 0.9618
# Epoch 52/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0852 - accuracy: 0.9711 - val_loss: 0.0679 - val_accuracy: 0.9618
# Epoch 53/100
# 633/633 [==============================] - 15s 24ms/step - loss: 0.0875 - accuracy: 0.9686 - val_loss: 0.0644 - val_accuracy: 0.9745
# Epoch 54/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0847 - accuracy: 0.9703 - val_loss: 0.0696 - val_accuracy: 0.9809
# Epoch 55/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0774 - accuracy: 0.9717 - val_loss: 0.0636 - val_accuracy: 0.9682
# Epoch 56/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0827 - accuracy: 0.9715 - val_loss: 0.0536 - val_accuracy: 0.9809
# Epoch 57/100
# 633/633 [==============================] - 14s 23ms/step - loss: 0.0776 - accuracy: 0.9759 - val_loss: 0.0605 - val_accuracy: 0.9745
# Epoch 58/100
# 633/633 [==============================] - 14s 23ms/step - loss: 0.0890 - accuracy: 0.9727 - val_loss: 0.0673 - val_accuracy: 0.9809
# Epoch 59/100
# 633/633 [==============================] - 14s 23ms/step - loss: 0.0739 - accuracy: 0.9747 - val_loss: 0.0979 - val_accuracy: 0.9618
# Epoch 60/100
# 633/633 [==============================] - 14s 23ms/step - loss: 0.0837 - accuracy: 0.9725 - val_loss: 0.0783 - val_accuracy: 0.9682
# Epoch 61/100
# 633/633 [==============================] - 14s 23ms/step - loss: 0.0763 - accuracy: 0.9739 - val_loss: 0.0760 - val_accuracy: 0.9618
# Epoch 62/100
# 633/633 [==============================] - 14s 23ms/step - loss: 0.0780 - accuracy: 0.9751 - val_loss: 0.0648 - val_accuracy: 0.9745
# Epoch 63/100
# 633/633 [==============================] - 14s 23ms/step - loss: 0.0785 - accuracy: 0.9741 - val_loss: 0.0563 - val_accuracy: 0.9682
# Epoch 64/100
# 633/633 [==============================] - 14s 23ms/step - loss: 0.0712 - accuracy: 0.9743 - val_loss: 0.0619 - val_accuracy: 0.9682
# Epoch 65/100
# 633/633 [==============================] - 14s 23ms/step - loss: 0.0753 - accuracy: 0.9753 - val_loss: 0.0819 - val_accuracy: 0.9682
# Epoch 66/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0731 - accuracy: 0.9741 - val_loss: 0.0623 - val_accuracy: 0.9618
# Epoch 67/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0733 - accuracy: 0.9761 - val_loss: 0.0842 - val_accuracy: 0.9618
# Epoch 68/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0766 - accuracy: 0.9749 - val_loss: 0.0824 - val_accuracy: 0.9618
# Epoch 69/100
# 633/633 [==============================] - 15s 23ms/step - loss: 0.0820 - accuracy: 0.9727 - val_loss: 0.0656 - val_accuracy: 0.9618
# Epoch 70/100
# 633/633 [==============================] - 15s 24ms/step - loss: 0.0743 - accuracy: 0.9753 - val_loss: 0.0778 - val_accuracy: 0.9745

# %%
#evaluate model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test_cat)

print()
print('Test Loss:\t', test_loss)
print('Test Accuracy:\t', test_acc)
# Out:
# 20/20 [==============================] - 1s 29ms/step - loss: 0.6793 - accuracy: 0.8734
#
# Test Loss:	 0.6792773008346558
# Test Accuracy:	 0.8733974099159241

# %%
#plot learning curves

fig, ax = plt.subplots(figsize=(8,6))

for metric in history.history:
    
    #subtract half epoch from training data
    if len(metric.split('_')) < 2:
        ax.plot(np.array(history.epoch), history.history[metric], label=metric)
    else:
        ax.plot(history.epoch, history.history[metric], label=metric)
    
ax.grid(True)    

ax.legend(fontsize=13);

# %%
# prediction on test set
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)

# compute the confusion matrix
conf_matrix = confusion_matrix(y_test, predicted_labels)
# Out:
# 20/20 [==============================] - 1s 29ms/step

# %%
# show the confusion matrix

class_labels = ["Normal", "Pneumonia"]

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
print(plt.show())
# Out:
# None

# %%
# Estrai i valori dalla matrice di confusione
tp = conf_matrix[0][0]
fp = conf_matrix[0][1]
fn = conf_matrix[1][0]
tn = conf_matrix[1][1]

# Calcola sensibilità (recall)
sensitivity = tp / (tp + fn)

# Calcola specificità
specificity = tn / (tn + fp)

print("Sensitività: {:.2f}".format(sensitivity))
print("Specificità: {:.2f}".format(specificity))
# Out:
# Sensitività: 0.99
# Specificità: 0.83

# %%
# Compute the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, predictions[:, 1])
roc_auc = auc(fpr, tpr)

# Show the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %%
# Define the prediction

y_test_pred = model.predict(X_test).argmax(axis=1)
# Out:
# 20/20 [==============================] - 1s 29ms/step

# %%
# Identify wrong predictions in the training set

idx_wrong = np.where(y_test_pred != y_test)[0] #positions of the wrongly classified data

num_wrong = len(idx_wrong)

# Show 10 wrong predictions the training set

fig, axs = plt.subplots(2,5,figsize=(12,4))

for i in range(10):
    
    ax = axs.ravel()[i]
    
    idx = idx_wrong[randrange(0, num_wrong)]
    
    ax.imshow(X_train[idx], cmap='gray')
    ax.set_title('TRUE: {}, PRED {}'.format(y_test[idx], y_test_pred[idx]), fontsize=13)
    ax.axis('off')
